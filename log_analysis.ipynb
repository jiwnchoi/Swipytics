# %%
import glob
import json

log_folder = "assets/logs/"
log_files = glob.glob(log_folder + "*.json")
logs = [json.load(open(log_file, "r")) for log_file in log_files]

# %%
def process_logs(logs: list[dict]):
  start_time = logs[0]["timestamp"]
  processed_logs = []

  for i, log in enumerate(logs):
    if log["event"] != "state":
      name = log["key"]
      value = None
      split_name = name.split("-")
      if "-" in name and len(split_name) > 1:
        name = split_name[0]
        value = split_name[1]

      if log["event"] == "scroll" and name == "chart_container":
        value = log["data"]["chartIndex"]

      if name == "prefer_chart":
        value = logs[i + 1]["data"][0]
        value = {
          "chartIndex": value["path"].split(".")[1],
          "preferred": value["value"],
        }

      processed_logs.append(
        {
          "pid": log["pid"],
          "timestamp": log["timestamp"] - start_time,
          "type": log["event"],
          "name": name,
          "value": value,
          "states": [],
        }
      )

    else:
      processed_logs[-1]["states"].append(log)

  return processed_logs


def extract_logs(log: list[dict], participant_id: int):
  splitted_logs = []
  start_idx = 0

  for i in range(len(log)):
    if log[i]["key"] == "load_demo":
      splitted_logs.append(log[start_idx:i])
      start_idx = i

  splitted_logs.append(log[start_idx:])
  filtered_logs = [log for log in splitted_logs if len(log) > 50]
  cars = [
    filtered_log
    for filtered_log in filtered_logs
    if filtered_log[1]["key"] == "data_store"
    and filtered_log[1]["data"][0]["value"] == "cars_ko.json"
  ][-1]

  cars = [{**car, "pid": f"P{participant_id}"} for car in cars]

  movies = [
    filtered_log
    for filtered_log in filtered_logs
    if filtered_log[1]["key"] == "data_store"
    and filtered_log[1]["data"][0]["value"] == "movies_ko.json"
  ][-1]

  movies = [{**movie, "pid": f"P{participant_id}"} for movie in movies]

  return cars, movies

# %%
cars_logs = [extract_logs(log, idx)[0] for idx, log in enumerate(logs)]
movies_logs = [extract_logs(log, idx)[1] for idx, log in enumerate(logs)]

# %%
processed_cars_logs = [process_logs(log) for log in cars_logs]
processed_movies_logs = [process_logs(log) for log in movies_logs]

# %%
from pprint import pprint


pprint(processed_cars_logs[0])
# Out:
# [{'name': 'load_demo',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'filename', 'value': 'cars_ko.json'}],
#               'event': 'state',
#               'key': 'data_store',
#               'pid': 'P0',
#               'timestamp': 1732523449104,
#               'version': 1},
#              {'data': [{'path': 'filename', 'value': 'cars_ko.json'}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523449118,
#               'version': 1},
#              {'data': [{'path': 'charts.0',
#                         'value': {'preferred': False,
#                                   'timestamp': 1732523449149,
#                                   'title': '연비'}},
#                        {'path': 'charts.1',
#                         'value': {'preferred': False,
#                                   'timestamp': 1732523449151,
#                                   'title': '실린더 수'}},
#                        {'path': 'currentChartIndex', 'value': 0}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523449159,
#               'version': 1},
#              {'data': [{'path': 'tabIndex', 'value': 0}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523449228,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 1}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523450641,
#               'version': 1},
#              {'data': [{'path': 'charts.2',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523450647,
#                                   'title': '배기량'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523450657,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 2}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523451107,
#               'version': 1}],
#   'timestamp': 0,
#   'type': 'click',
#   'value': None},
#  {'name': 'chart_container',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.3',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523451114,
#                                   'title': '제조국'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523451122,
#               'version': 1}],
#   'timestamp': 2020,
#   'type': 'scroll',
#   'value': 2},
#  {'name': 'prefer_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.2.preferred', 'value': True},
#                        {'path': 'charts.3'}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523452169,
#               'version': 1},
#              {'data': [{'path': 'charts.3',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523452178,
#                                   'title': '실린더 수 & 배기량'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523452206,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 3}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523452691,
#               'version': 1},
#              {'data': [{'path': 'charts.4',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523452700,
#                                   'title': '연비 & 배기량'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523452706,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 4}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523453091,
#               'version': 1},
#              {'data': [{'path': 'charts.5',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523453099,
#                                   'title': '배기량 & 제조국'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523453105,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 5}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523453424,
#               'version': 1}],
#   'timestamp': 3080,
#   'type': 'double_tap',
#   'value': {'chartIndex': '2', 'preferred': True}},
#  {'name': 'chart_container',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.6',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523453448,
#                                   'title': '배기량 & 무게 (파운드)'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523453450,
#               'version': 1}],
#   'timestamp': 4337,
#   'type': 'scroll',
#   'value': 5},
#  {'name': 'prefer_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.5.preferred', 'value': True},
#                        {'path': 'charts.6'}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523454437,
#               'version': 1},
#              {'data': [{'path': 'charts.6',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523454451,
#                                   'title': '연비 & 제조국'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523454478,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 6}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523455008,
#               'version': 1},
#              {'data': [{'path': 'charts.7',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523455019,
#                                   'title': '배기량 & 가속 성능'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523455026,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 7}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523455375,
#               'version': 1},
#              {'data': [{'path': 'charts.8',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523455386,
#                                   'title': '배기량 & 마력'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523455393,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 8}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523455691,
#               'version': 1}],
#   'timestamp': 5346,
#   'type': 'double_tap',
#   'value': {'chartIndex': '5', 'preferred': True}},
#  {'name': 'chart_container',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.9',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523455710,
#                                   'title': '배기량 & 생산 연도'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523455739,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 9}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523456075,
#               'version': 1},
#              {'data': [{'path': 'charts.10',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523456082,
#                                   'title': '생산 연도 & 제조국'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523456090,
#               'version': 1}],
#   'timestamp': 6604,
#   'type': 'scroll',
#   'value': 8},
#  {'name': 'prefer_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.9.preferred', 'value': True},
#                        {'path': 'charts.10'}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523456960,
#               'version': 1},
#              {'data': [{'path': 'charts.10',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523456971,
#                                   'title': '생산 연도'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523457003,
#               'version': 1},
#              {'data': [{'path': 'tabIndex', 'value': 1}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523457944,
#               'version': 1}],
#   'timestamp': 7870,
#   'type': 'double_tap',
#   'value': {'chartIndex': '9', 'preferred': True}},
#  {'name': 'tab',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'searchTargetFieldNames.0', 'value': '실린더 수'}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523458640,
#               'version': 1}],
#   'timestamp': 8868,
#   'type': 'click',
#   'value': 'search'},
#  {'name': 'search_tag',
#   'pid': 'P0',
#   'states': [],
#   'timestamp': 9569,
#   'type': 'click',
#   'value': '실린더 수'},
#  {'name': 'append_discovered_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.10.title', 'value': '실린더 수'},
#                        {'path': 'charts.10.timestamp', 'value': 1732523459289},
#                        {'path': 'charts.10.generatedBy', 'value': 'append'},
#                        {'path': 'charts.11',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523459287,
#                                   'title': '배기량 & 생산 연도 & 제조국'}},
#                        {'path': 'currentChartIndex', 'value': 10}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523459289,
#               'version': 1},
#              {'data': [{'path': 'tabIndex', 'value': 0}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523459316,
#               'version': 1},
#              {'data': [{'path': 'tabIndex', 'value': 2}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523460642,
#               'version': 1}],
#   'timestamp': 10176,
#   'type': 'click',
#   'value': '실린더 수'},
#  {'name': 'tab',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'tabIndex', 'value': 0}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523461210,
#               'version': 1}],
#   'timestamp': 11568,
#   'type': 'click',
#   'value': 'likes'},
#  {'name': 'move_to_preferred_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'currentChartIndex', 'value': 2}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523461362,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 10}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523462685,
#               'version': 1},
#              {'data': [{'path': 'tabIndex', 'value': 2}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523463769,
#               'version': 1}],
#   'timestamp': 12137,
#   'type': 'click',
#   'value': '배기량'},
#  {'name': 'tab',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'tabIndex', 'value': 0}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523464334,
#               'version': 1}],
#   'timestamp': 14696,
#   'type': 'click',
#   'value': 'likes'},
#  {'name': 'move_to_preferred_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'currentChartIndex', 'value': 5}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523464486,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 10}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523465310,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 11}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523466208,
#               'version': 1}],
#   'timestamp': 15259,
#   'type': 'click',
#   'value': '배기량 & 제조국'},
#  {'name': 'chart_container',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.12',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523466234,
#                                   'title': '실린더 수 & 생산 연도'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523466237,
#               'version': 1},
#              {'data': [{'path': 'currentChartIndex', 'value': 12}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523467875,
#               'version': 1}],
#   'timestamp': 17121,
#   'type': 'scroll',
#   'value': 11},
#  {'name': 'chart_container',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.13',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523467900,
#                                   'title': '마력 & 생산 연도'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523467902,
#               'version': 1},
#              {'data': [{'path': 'charts.12.preferred', 'value': True},
#                        {'path': 'charts.13'}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523469642,
#               'version': 1}],
#   'timestamp': 18788,
#   'type': 'scroll',
#   'value': 12},
#  {'name': 'prefer_chart',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.13',
#                         'value': {'generatedBy': 'scroll',
#                                   'preferred': False,
#                                   'timestamp': 1732523469654,
#                                   'title': '가속 성능 & 생산 연도'}}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523469683,
#               'version': 1},
#              {'data': [{'path': 'tabIndex', 'value': -1}],
#               'event': 'state',
#               'key': 'interaction_store',
#               'pid': 'P0',
#               'timestamp': 1732523473282,
#               'version': 1}],
#   'timestamp': 20589,
#   'type': 'click',
#   'value': {'chartIndex': '13',
#             'preferred': {'generatedBy': 'scroll',
#                           'preferred': False,
#                           'timestamp': 1732523469654,
#                           'title': '가속 성능 & 생산 연도'}}},
#  {'name': 'settings_button',
#   'pid': 'P0',
#   'states': [],
#   'timestamp': 24205,
#   'type': 'click',
#   'value': None},
#  {'name': 'share_charts',
#   'pid': 'P0',
#   'states': [],
#   'timestamp': 30265,
#   'type': 'click',
#   'value': None},
#  {'name': 'select',
#   'pid': 'P0',
#   'states': [{'data': [{'path': 'charts.0'},
#                        {'path': 'charts.1'},
#                        {'path': 'charts.2'},
#                        {'path': 'charts.3'},
#                        {'path': 'charts.4'},
#                        {'path': 'charts.5'},
#                        {'path': 'charts.6'},
#                        {'path': 'charts.7'},
#                        {'path': 'charts.8'},
#                        {'path': 'charts.9'},
#                        {'path': 'charts.10'},
#                        {'path': 'charts.11'},
#                        {'path': 'charts.12'},
#                        {'path': 'charts.13'},
#                        {'path': 'filename', 'value': ''},
#                        {'path': 'currentChartIndex', 'value': -1}],
#               'event': 'state',
#               'key': 'session_store',
#               'pid': 'P0',
#               'timestamp': 1732523483332,
#               'version': 1}],
#   'timestamp': 34064,
#   'type': 'change',
#   'value': 'demo'}]
