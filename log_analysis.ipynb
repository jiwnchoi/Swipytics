# %%
import glob
import json

log_folder = "assets/logs/"
log_files = glob.glob(log_folder + "*.json")
log_files = [log for log in log_files if "p4" in log]
logs = [json.load(open(log_file, "r")) for log_file in log_files]

# %%
def process_logs(logs: list[dict]):
  start_time = logs[0]["timestamp"]
  processed_logs = []

  for i, log in enumerate(logs):
    if log["event"] != "state":
      name = log["key"]
      value = None
      split_name = name.split("-")
      if "-" in name and len(split_name) > 1:
        name = split_name[0]
        value = split_name[1]

      if log["event"] == "scroll" and name == "chart_container":
        value = log["data"]["chartIndex"]

      if name == "prefer_chart":
        value = logs[i + 1]["data"][0]
        value = {
          "chartIndex": value["path"].split(".")[1],
          "preferred": value["value"],
        }

      processed_logs.append(
        {
          "pid": log["pid"],
          "timestamp": log["timestamp"] - start_time,
          "type": log["event"],
          "name": name,
          "value": value,
          "states": [],
        }
      )

    else:
      processed_logs[-1]["states"].append(log)

  return processed_logs


def extract_logs(log: list[dict], participant_id: int):
  splitted_logs = []
  start_idx = 0

  for i in range(len(log)):
    if log[i]["key"] == "load_demo":
      splitted_logs.append(log[start_idx:i])
      start_idx = i

  splitted_logs.append(log[start_idx:])
  filtered_logs = [log for log in splitted_logs if len(log) > 50]
  cars = [
    filtered_log
    for filtered_log in filtered_logs
    if filtered_log[1]["key"] == "data_store"
    and filtered_log[1]["data"][0]["value"] == "cars_ko.json"
  ][-1]

  cars = [{**car, "pid": f"P{participant_id}"} for car in cars]

  movies = [
    filtered_log
    for filtered_log in filtered_logs
    if filtered_log[1]["key"] == "data_store"
    and filtered_log[1]["data"][0]["value"] == "movies_ko.json"
  ][-1]

  movies = [{**movie, "pid": f"P{participant_id}"} for movie in movies]

  return cars, movies

# %%
cars_logs = [extract_logs(log, idx)[0] for idx, log in enumerate(logs)]
movies_logs = [extract_logs(log, idx)[1] for idx, log in enumerate(logs)]

# %%
processed_cars_logs = [process_logs(log) for log in cars_logs]
processed_movies_logs = [process_logs(log) for log in movies_logs]

# %%
processed_movies_logs
# Out:
# [[{'pid': 'P0',
#    'timestamp': 0,
#    'type': 'click',
#    'name': 'load_demo',
#    'value': None,
#    'states': [{'timestamp': 1732604986700,
#      'key': 'data_store',
#      'event': 'state',
#      'data': [{'path': 'filename', 'value': 'movies_ko.json'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732604986719,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'filename', 'value': 'movies_ko.json'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732604987060,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.0',
#        'value': {'title': '개봉일',
#         'preferred': False,
#         'timestamp': 1732604986462}},
#       {'path': 'charts.1',
#        'value': {'title': 'IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732604986465}},
#       {'path': 'currentChartIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732604987115,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605067055,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 80497,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 1,
#    'states': [{'timestamp': 1732605067113,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.2',
#        'value': {'title': '상영 시간 (분)',
#         'preferred': False,
#         'timestamp': 1732605066599,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605067702,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605087394,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 100828,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 1,
#    'states': [{'timestamp': 1732605088475,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 101909,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 0,
#    'states': [{'timestamp': 1732605089029,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605103530,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 2}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 116964,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 2,
#    'states': [{'timestamp': 1732605103572,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.3',
#        'value': {'title': '영화 관람 등급',
#         'preferred': False,
#         'timestamp': 1732605103066,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605112663,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 3}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 126097,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 3,
#    'states': [{'timestamp': 1732605112717,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.4',
#        'value': {'title': '미국 DVD 판매 ($)',
#         'preferred': False,
#         'timestamp': 1732605112211,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605125854,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 4}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 139288,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 4,
#    'states': [{'timestamp': 1732605125903,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.5',
#        'value': {'title': '미국 수익 ($)',
#         'preferred': False,
#         'timestamp': 1732605125393,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605133230,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 5}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 146665,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 5,
#    'states': [{'timestamp': 1732605133276,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.6',
#        'value': {'title': 'IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605132768,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605137435,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 6}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 150869,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 6,
#    'states': [{'timestamp': 1732605137480,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.7',
#        'value': {'title': '제작 예산 ($)',
#         'preferred': False,
#         'timestamp': 1732605136968,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605139868,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 7}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 153302,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 7,
#    'states': [{'timestamp': 1732605139915,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.8',
#        'value': {'title': '로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605139408,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605141371,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 6}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 154806,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 6,
#    'states': [{'timestamp': 1732605146952,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 7}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 160386,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 7,
#    'states': [{'timestamp': 1732605148927,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 8}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 162361,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 8,
#    'states': [{'timestamp': 1732605148977,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.9',
#        'value': {'title': '창작 유형',
#         'preferred': False,
#         'timestamp': 1732605148467,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605156505,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 9}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 169939,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 9,
#    'states': [{'timestamp': 1732605156557,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.10',
#        'value': {'title': '전세계 수익 ($)',
#         'preferred': False,
#         'timestamp': 1732605156045,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605161585,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 175019,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 10,
#    'states': [{'timestamp': 1732605161647,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.11',
#        'value': {'title': '로튼 토마토 평점 & IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605161134,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605163631,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605163673,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.12',
#        'value': {'title': '전세계 수익 ($) & IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605163167,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605173327,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 186761,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605173374,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.13',
#        'value': {'title': '창작 유형 & 로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605172866,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605188457,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 13}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 201891,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 13,
#    'states': [{'timestamp': 1732605188513,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.14',
#        'value': {'title': '제작 예산 ($) & IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605188002,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605198928,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 212363,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605199323,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605199838,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 213272,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 10,
#    'states': [{'timestamp': 1732605200111,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 9}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 213545,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 9,
#    'states': [{'timestamp': 1732605200479,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 8}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 213913,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 8,
#    'states': [{'timestamp': 1732605200699,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 9}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605207717,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 221151,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 10,
#    'states': [{'timestamp': 1732605208226,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 221660,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 11,
#    'states': [{'timestamp': 1732605208865,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 222299,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605209502,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 13}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 222936,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 13,
#    'states': [{'timestamp': 1732605213524,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 226958,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605213848,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605214454,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 227888,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 10,
#    'states': [{'timestamp': 1732605214845,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 9}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 228279,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 9,
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 229500,
#    'type': 'double_tap',
#    'name': 'prefer_chart',
#    'value': {'chartIndex': '9', 'preferred': True},
#    'states': [{'timestamp': 1732605216077,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.9.preferred', 'value': True},
#       {'path': 'charts.14'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605216147,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.14',
#        'value': {'title': '창작 유형 & IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605215611,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605216485,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605216852,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 230286,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 11,
#    'states': [{'timestamp': 1732605217192,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 230626,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605217729,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 13}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 231163,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 13,
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 232240,
#    'type': 'double_tap',
#    'name': 'prefer_chart',
#    'value': {'chartIndex': '13', 'preferred': True},
#    'states': [{'timestamp': 1732605218810,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.13.preferred', 'value': True},
#       {'path': 'charts.14'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605218864,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.14',
#        'value': {'title': '전세계 수익 ($) & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605218347,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605219216,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 14}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 232650,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 14,
#    'states': [{'timestamp': 1732605219267,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.15',
#        'value': {'title': '제작 예산 ($) & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605218756,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605224849,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 13}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 238283,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 13,
#    'states': [{'timestamp': 1732605227587,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 241021,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605227869,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605228363,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 241797,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 10,
#    'states': [{'timestamp': 1732605228635,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 9}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 242069,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 9,
#    'states': [{'timestamp': 1732605229874,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 8}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 243308,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 8,
#    'states': [{'timestamp': 1732605231308,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 9}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 244742,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 9,
#    'states': [{'timestamp': 1732605232125,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 10}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605232404,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 11}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 245838,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 11,
#    'states': [{'timestamp': 1732605232897,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 12}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 246331,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 12,
#    'states': [{'timestamp': 1732605233178,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 13}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 246612,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 13,
#    'states': [{'timestamp': 1732605233476,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 14}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 246910,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 14,
#    'states': [{'timestamp': 1732605236912,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 15}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605236974,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.16',
#        'value': {'title': '미국 수익 ($) & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605236458,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605239064,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 16}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 252499,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 16,
#    'states': [{'timestamp': 1732605239119,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.17',
#        'value': {'title': '제작 예산 ($) & 로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605238603,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605241360,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 17}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 254794,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 17,
#    'states': [{'timestamp': 1732605241414,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.18',
#        'value': {'title': '창작 유형 & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605240904,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605245990,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 18}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 259425,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 18,
#    'states': [{'timestamp': 1732605246049,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.19',
#        'value': {'title': '미국 DVD 판매 ($) & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605245540,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605248287,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 19}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 261721,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 19,
#    'states': [{'timestamp': 1732605248338,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.20',
#        'value': {'title': '상영 시간 (분) & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605247828,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605250831,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 20}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 264265,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 20,
#    'states': [{'timestamp': 1732605250873,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.21',
#        'value': {'title': '로튼 토마토 평점 & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605250365,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605252871,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 21}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 266305,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 21,
#    'states': [{'timestamp': 1732605252919,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.22',
#        'value': {'title': '개봉일 & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605252408,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605257661,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 22}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 271095,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 22,
#    'states': [{'timestamp': 1732605257725,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.23',
#        'value': {'title': '미국 DVD 판매 ($) & 로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605257209,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605266777,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.22.preferred', 'value': True},
#       {'path': 'charts.23'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605266844,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.23',
#        'value': {'title': '상영 시간 (분) & 로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605266325,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605267426,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 23}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 280860,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 23,
#    'states': [{'timestamp': 1732605267474,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.24',
#        'value': {'title': '개봉일 & 로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605266963,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605268815,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 22}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 282250,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 22,
#    'states': [{'timestamp': 1732605269945,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.22.preferred', 'value': False},
#       {'path': 'charts.24'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 283391,
#    'type': 'click',
#    'name': 'prefer_chart',
#    'value': {'chartIndex': '24',
#     'preferred': {'title': '개봉일 & 로튼 토마토 평점 & 창작 유형',
#      'preferred': False,
#      'timestamp': 1732605269533,
#      'generatedBy': 'scroll'}},
#    'states': [{'timestamp': 1732605270047,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.24',
#        'value': {'title': '개봉일 & 로튼 토마토 평점 & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605269533,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605270557,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 23}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 283991,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 23,
#    'states': [{'timestamp': 1732605273297,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 24}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 286731,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 24,
#    'states': [{'timestamp': 1732605273354,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.25',
#        'value': {'title': '로튼 토마토 평점 & IMDB 평점 & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605272838,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605302374,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.24.preferred', 'value': True},
#       {'path': 'charts.25'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605302443,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.25',
#        'value': {'title': '개봉일 & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605301925,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605303030,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 25}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 316464,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 25,
#    'states': [{'timestamp': 1732605303078,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.26',
#        'value': {'title': '미국 DVD 판매 ($) & 개봉일',
#         'preferred': False,
#         'timestamp': 1732605302566,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605311792,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.25.preferred', 'value': True},
#       {'path': 'charts.26'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605311879,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.26',
#        'value': {'title': '개봉일 & 상영 시간 (분)',
#         'preferred': False,
#         'timestamp': 1732605311370,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605314464,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 24}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 327899,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 24,
#    'states': [{'timestamp': 1732605317076,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 25}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 330510,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 25,
#    'states': [{'timestamp': 1732605320001,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 26}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 333436,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 26,
#    'states': [{'timestamp': 1732605320164,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.27',
#        'value': {'title': '개봉일 & IMDB 평점 & 창작 유형',
#         'preferred': False,
#         'timestamp': 1732605319599,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 342225,
#    'type': 'double_tap',
#    'name': 'prefer_chart',
#    'value': {'chartIndex': '26', 'preferred': True},
#    'states': [{'timestamp': 1732605328795,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.26.preferred', 'value': True},
#       {'path': 'charts.27'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605328845,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.27',
#        'value': {'title': '개봉일 & 영화 관람 등급',
#         'preferred': False,
#         'timestamp': 1732605328330,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605329257,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 27}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 342692,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 27,
#    'states': [{'timestamp': 1732605329312,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.28',
#        'value': {'title': '상영 시간 (분) & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605328797,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605335144,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 28}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 348579,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 28,
#    'states': [{'timestamp': 1732605335231,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.29',
#        'value': {'title': '미국 수익 ($) & 개봉일',
#         'preferred': False,
#         'timestamp': 1732605334704,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605337485,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 29}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 350920,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 29,
#    'states': [{'timestamp': 1732605337549,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.30',
#        'value': {'title': '제작 예산 ($) & 개봉일',
#         'preferred': False,
#         'timestamp': 1732605337032,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605342756,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 30}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 356191,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 30,
#    'states': [{'timestamp': 1732605342842,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.31',
#        'value': {'title': '개봉일 & IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605342324,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605345624,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 29}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 359058,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 29,
#    'states': [{'timestamp': 1732605353247,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 30}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 366681,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 30,
#    'states': [{'timestamp': 1732605366286,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 31}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 379721,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 31,
#    'states': [{'timestamp': 1732605366351,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.32',
#        'value': {'title': '전세계 수익 ($) & 개봉일',
#         'preferred': False,
#         'timestamp': 1732605365836,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605377174,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 32}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 390608,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 32,
#    'states': [{'timestamp': 1732605377241,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.33',
#        'value': {'title': '제작 예산 ($) & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605376721,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605387216,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 33}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 400650,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 33,
#    'states': [{'timestamp': 1732605387315,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.34',
#        'value': {'title': '전세계 수익 ($) & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605386803,
#         'generatedBy': 'scroll'}}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605388956,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'currentChartIndex', 'value': 32}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 402390,
#    'type': 'scroll',
#    'name': 'chart_container',
#    'value': 32,
#    'states': [{'timestamp': 1732605392115,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 405571,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': [{'timestamp': 1732605393913,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 407365,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '개봉일',
#    'states': [{'timestamp': 1732605395898,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': '전세계 수익 ($)'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 409346,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '전세계 수익 ($)',
#    'states': [{'timestamp': 1732605401932,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2', 'value': 'IMDB 투표수'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 415382,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': 'IMDB 투표수',
#    'states': [{'timestamp': 1732605404328,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'},
#       {'path': 'searchTargetFieldNames.1', 'value': '전세계 수익 ($)'},
#       {'path': 'searchTargetFieldNames.2'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 417772,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': 'IMDB 투표수',
#    'states': [{'timestamp': 1732605405405,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2', 'value': '미국 수익 ($)'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 418861,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '미국 수익 ($)',
#    'states': [{'timestamp': 1732605405725,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 419176,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '전세계 수익 ($)',
#    'states': [{'timestamp': 1732605406474,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2', 'value': 'IMDB 투표수'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 419925,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': 'IMDB 투표수',
#    'states': [{'timestamp': 1732605407588,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'},
#       {'path': 'searchTargetFieldNames.1', 'value': '미국 수익 ($)'},
#       {'path': 'searchTargetFieldNames.2'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 421041,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': 'IMDB 투표수',
#    'states': [{'timestamp': 1732605411636,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2', 'value': '전세계 수익 ($)'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 425086,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '전세계 수익 ($)',
#    'states': [{'timestamp': 1732605412366,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 425818,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '전세계 수익 ($)',
#    'states': [{'timestamp': 1732605413990,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.2', 'value': '제작 예산 ($)'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 427442,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '제작 예산 ($)',
#    'states': [{'timestamp': 1732605414520,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': '제작 예산 ($)'},
#       {'path': 'searchTargetFieldNames.2'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 427970,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '미국 수익 ($)',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 430320,
#    'type': 'click',
#    'name': 'append_discovered_chart',
#    'value': '제작 예산 ($) & 개봉일',
#    'states': [{'timestamp': 1732605416966,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.34.title', 'value': '제작 예산 ($) & 개봉일'},
#       {'path': 'charts.34.timestamp', 'value': 1732605416965},
#       {'path': 'charts.34.generatedBy', 'value': 'append'},
#       {'path': 'charts.35',
#        'value': {'title': 'IMDB 평점 & IMDB 투표수',
#         'preferred': False,
#         'timestamp': 1732605416448,
#         'generatedBy': 'scroll'}},
#       {'path': 'currentChartIndex', 'value': 34}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605416999,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605417000,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0'},
#       {'path': 'searchTargetFieldNames.1'}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605424944,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 438388,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': [{'timestamp': 1732605426017,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 439467,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '개봉일',
#    'states': [{'timestamp': 1732605427709,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': '미국 수익 ($)'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 441159,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '미국 수익 ($)',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 442191,
#    'type': 'click',
#    'name': 'append_discovered_chart',
#    'value': '미국 수익 ($) & 개봉일',
#    'states': [{'timestamp': 1732605428843,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.35.title', 'value': '미국 수익 ($) & 개봉일'},
#       {'path': 'charts.35.timestamp', 'value': 1732605428841},
#       {'path': 'charts.35.generatedBy', 'value': 'append'},
#       {'path': 'charts.36',
#        'value': {'title': '미국 수익 ($) & IMDB 평점',
#         'preferred': False,
#         'timestamp': 1732605428326,
#         'generatedBy': 'scroll'}},
#       {'path': 'currentChartIndex', 'value': 35}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605428880,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605432625,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 446082,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': [{'timestamp': 1732605433417,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 446871,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '개봉일',
#    'states': [{'timestamp': 1732605434838,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': '제작 예산 ($)'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 448289,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '제작 예산 ($)',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 449451,
#    'type': 'click',
#    'name': 'append_discovered_chart',
#    'value': '제작 예산 ($) & 개봉일',
#    'states': [{'timestamp': 1732605436096,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.36.title', 'value': '제작 예산 ($) & 개봉일'},
#       {'path': 'charts.36.timestamp', 'value': 1732605436095},
#       {'path': 'charts.36.generatedBy', 'value': 'append'},
#       {'path': 'charts.37',
#        'value': {'title': '제작 예산 ($) & 상영 시간 (분)',
#         'preferred': False,
#         'timestamp': 1732605435579,
#         'generatedBy': 'scroll'}},
#       {'path': 'currentChartIndex', 'value': 36}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605436123,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605443769,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 457221,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': [{'timestamp': 1732605444437,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 457887,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '개봉일',
#    'states': [{'timestamp': 1732605446701,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': 'IMDB 평점'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 460153,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': 'IMDB 평점',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 461025,
#    'type': 'click',
#    'name': 'append_discovered_chart',
#    'value': '개봉일 & IMDB 평점',
#    'states': [{'timestamp': 1732605447667,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.37.title', 'value': '개봉일 & IMDB 평점'},
#       {'path': 'charts.37.timestamp', 'value': 1732605447666},
#       {'path': 'charts.37.generatedBy', 'value': 'append'},
#       {'path': 'charts.38',
#        'value': {'title': '미국 수익 ($) & 제작 예산 ($)',
#         'preferred': False,
#         'timestamp': 1732605447153,
#         'generatedBy': 'scroll'}},
#       {'path': 'currentChartIndex', 'value': 37}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605447697,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605453763,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 467218,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': [{'timestamp': 1732605454437,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 467889,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '개봉일',
#    'states': [{'timestamp': 1732605455496,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': '로튼 토마토 평점'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 468945,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '로튼 토마토 평점',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 470158,
#    'type': 'click',
#    'name': 'append_discovered_chart',
#    'value': '개봉일 & 로튼 토마토 평점',
#    'states': [{'timestamp': 1732605456811,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.38.title', 'value': '개봉일 & 로튼 토마토 평점'},
#       {'path': 'charts.38.timestamp', 'value': 1732605456810},
#       {'path': 'charts.38.generatedBy', 'value': 'append'},
#       {'path': 'charts.39',
#        'value': {'title': '미국 수익 ($) & 상영 시간 (분)',
#         'preferred': False,
#         'timestamp': 1732605456296,
#         'generatedBy': 'scroll'}},
#       {'path': 'currentChartIndex', 'value': 38}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605456838,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605460983,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 474433,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': [{'timestamp': 1732605462976,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.0', 'value': '개봉일'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 476432,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': '개봉일',
#    'states': [{'timestamp': 1732605464020,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'searchTargetFieldNames.1', 'value': 'IMDB 투표수'}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 477465,
#    'type': 'click',
#    'name': 'search_tag',
#    'value': 'IMDB 투표수',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 478122,
#    'type': 'click',
#    'name': 'append_discovered_chart',
#    'value': '개봉일 & IMDB 투표수',
#    'states': [{'timestamp': 1732605464777,
#      'key': 'session_store',
#      'event': 'state',
#      'data': [{'path': 'charts.39.title', 'value': '개봉일 & IMDB 투표수'},
#       {'path': 'charts.39.timestamp', 'value': 1732605464776},
#       {'path': 'charts.39.generatedBy', 'value': 'append'},
#       {'path': 'charts.40',
#        'value': {'title': '미국 수익 ($) & 로튼 토마토 평점',
#         'preferred': False,
#         'timestamp': 1732605464260,
#         'generatedBy': 'scroll'}},
#       {'path': 'currentChartIndex', 'value': 39}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605464808,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 0}],
#      'version': 1,
#      'pid': 'P0'},
#     {'timestamp': 1732605472892,
#      'key': 'interaction_store',
#      'event': 'state',
#      'data': [{'path': 'tabIndex', 'value': 1}],
#      'version': 1,
#      'pid': 'P0'}]},
#   {'pid': 'P0',
#    'timestamp': 486342,
#    'type': 'click',
#    'name': 'tab',
#    'value': 'search',
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 508202,
#    'type': 'click',
#    'name': 'share_charts',
#    'value': None,
#    'states': []},
#   {'pid': 'P0',
#    'timestamp': 520673,
#    'type': 'click',
#    'name': 'share_logs',
#    'value': None,
#    'states': []}]]

# %%
def extract_charts_from_log(log_data):
  # Dictionary to store charts with index as key
  charts = {}

  # Go through each event in the log
  for event in log_data:
    # Check states in each event
    if "states" in event:
      for state in event["states"]:
        # Check if there's data in the state
        if "data" in state:
          for data_item in state["data"]:
            # Extract path and check if it starts with 'charts'
            path = data_item.get("path", "")
            if path.startswith("charts."):
              # Parse the chart index and remaining path
              path_parts = path.split(".")
              if len(path_parts) < 2:
                continue

              chart_idx = path_parts[1]

              # Handle the case where it's updating a specific field
              if len(path_parts) > 2:
                # If this is a preferred update
                if path_parts[2] == "preferred":
                  if chart_idx in charts:
                    charts[chart_idx]["preferred"] = data_item["value"]
                continue

              # If it's a full chart value, update or add it
              if "value" in data_item:
                charts[chart_idx] = data_item["value"]

  # Convert dictionary to list, sorting by index
  chart_list = []
  for idx in sorted(charts.keys(), key=lambda x: int(x)):
    chart_list.append(charts[idx])

  return chart_list


def process_charts(chart_list):
  # Process charts to match desired output format
  processed_charts = []
  for chart in chart_list:
    # Count number of fields based on & in title
    n_fields = chart["title"].count("&") + 1

    processed_chart = {
      "title": chart["title"],
      "n_fields": n_fields,
      "preferred": chart.get("preferred", False),
      "generatedBy": chart.get("generatedBy", None),
    }
    processed_charts.append(processed_chart)

  return processed_charts


# Example usage:
# raw_charts = extract_charts_from_log(log_data)
# final_charts = process_charts(raw_charts)

# %%
print(len(processed_movies_logs[0]))

c = extract_charts_from_log(processed_movies_logs[0])
cc = process_charts(c)

json.dump(cc, open("assets/sessions/p4-movies.json", "w"), indent=2, ensure_ascii=False)
# Out:
# 108
